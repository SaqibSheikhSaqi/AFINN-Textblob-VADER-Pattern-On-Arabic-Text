# %%
from textblob import TextBlob
import xlsxwriter

# %%
import pandas as pd
import numpy
df=pd.read_excel('D:\AffinArabic\DataSet\AabicToEnglishDataset.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0                                             Arabic  \
# 0           0                         سيئ جدا بعد الإصدار الجديد
# 1           1                                  ابلكيشن زباله بجد
# 2           2                                 سيئ التطبيق لايعمل
# 3           3  للأسف التطبيق للأسوأ كان جدا رائع وسهل وبسيط ا...
# 4           4                     التحديث بطيئ جدا جدا عند الفتح
#
#                                              English     Class
# 0                      Too bad after the new version  Negative
# 1                         Really rubbish application  Negative
# 2                                Bad app not working  Negative
# 3  Unfortunately, for the worst, the application ...  Negative
# 4               The update is very slow when opening  Negative

# %%
sentences=df['English']
actual_class=df['Class']
ArabicSentences=df['Arabic']

# %%
# Example text
predicted_class=[]
workbook = xlsxwriter.Workbook('D:\AffinArabic\output\ArabicSentimentAnalysisUsing-Textblob.xlsx')
worksheet1 = workbook.add_worksheet()
row=0

worksheet1.write(row, 0, str("Arabic Sentence"))
worksheet1.write(row, 1, str("English Sentence"))
worksheet1.write(row, 2, str("Actual Class"))
worksheet1.write(row, 3, str("Predicted Score"))
worksheet1.write(row, 4, str("Predicted Class"))
i=0

for text in sentences:
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity
    if sentiment_polarity > 0:
        sentiment = 'Positive'
        predicted_class.append('Positive')
    elif sentiment_polarity <= 0:
        sentiment = 'Negative'
        predicted_class.append('Negative')


    # Output results
    print(f"Text: {text}")
    print(f"Sentiment Polarity: {sentiment_polarity}")
    print(f"Sentiment: {sentiment}")
    row=row+1
    worksheet1.write(row, 0, str(ArabicSentences[i]))
    worksheet1.write(row, 1, str(text))
    worksheet1.write(row, 2, str(actual_class[i]))
    worksheet1.write(row, 3, str(sentiment_polarity))
    worksheet1.write(row, 4, str(sentiment))
    i=i+1
workbook.close()
# Out:
# Text: Too bad after the new version
# Sentiment Polarity: -0.28181818181818175
# Sentiment: Negative
# Text: Really rubbish application
# Sentiment Polarity: 0.2
# Sentiment: Positive
# Text: Bad app not working
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: Unfortunately, for the worst, the application was very wonderful, easy, and simple. Now it is complicated and does not open with you easily, and you do not find all the services available to you
# Sentiment Polarity: 0.029629629629629634
# Sentiment: Positive
# Text: The update is very slow when opening
# Sentiment Polarity: -0.39000000000000007
# Sentiment: Negative
# Text: Pass it by after the last update, it never opened, and it refuses any password you write or the card number .. Al-Ahly ruined the application that most people used to rely on, unfortunately
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The application does not work. Every time I log in to my account, it does not open. Look for a solution. I am disabled
# Sentiment Polarity: -0.1
# Sentiment: Negative
# Text: Unfortunately, it is very bad. Since yesterday, I am trying to use it. I contacted customer services, and he said, delete it and download it again. It may be an update, and the same problem has not been resolved.
# Sentiment Polarity: -0.4549999999999999
# Sentiment: Negative
# Text: Honestly, it's unfortunate
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: very bad
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: Bad application Al-Rajhi is better than you
# Sentiment Polarity: -0.09999999999999992
# Sentiment: Negative
# Text: Unfortunately, it does not deserve any evaluation
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: God suffices them, and He is the best disposer of affairs, updating garbage. Go up, Al Ahly Bank. Technology is advancing, and you are backward
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: It is one of the worst programs that you can use technically. I expect its budget to be ten riyals, including tax
# Sentiment Polarity: -0.3333333333333333
# Sentiment: Negative
# Text: Unfortunately, after the update, it does not work and has many problems, and we did not benefit from it, especially outside the Kingdom
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very poor service and useless updates
# Sentiment Polarity: -0.51
# Sentiment: Negative
# Text: Too bad the one before it is better and faster. This application does not complete the full entry and does not make transfers. Bad. puny. You have a lot of faults. The developer of the application is a failure, a failure, and the bank is a failure from it. Then you take fees and service
# Sentiment Polarity: -0.19374999999999995
# Sentiment: Negative
# Text: The old program is better, bad, and its updates do not work and are not successful
# Sentiment Polarity: -0.11874999999999997
# Sentiment: Negative
# Text: lousy
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: It doesn't work for me ten hours while I'm sitting on it, it doesn't work
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: very awful . Every time I come in, it tells me the information is wrong, and I wrote it in a note!!
# Sentiment Polarity: -0.890625
# Sentiment: Negative
# Text: Every beneficiary host refuses
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The worst bank in history
# Sentiment Polarity: -1.0
# Sentiment: Negative
# Text: The application does not open for me, please solve the problem
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Whoever fails me fails, and it is clear that everything is complicated. The application is considered to facilitate, not to complicate
# Sentiment Polarity: -0.35
# Sentiment: Negative
# Text: Integration does not improve your services. You must look at the problem....
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Bad bank, they close the account on strange things to sign, and the problem is not solved from the first visit. You need to stay with them in the branch in order to return the account
# Sentiment Polarity: -0.16666666666666663
# Sentiment: Negative
# Text: After the update it got really bad
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: Khara costume
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: not good
# Sentiment Polarity: -0.35
# Sentiment: Negative
# Text: The application does not work properly and always requires us to visit the branch to complete any transaction. I advise those in charge of the program to solve these problems as soon as possible. The application has become very, very, very bad. We hope to develop confidential solutions
# Sentiment Polarity: -0.20249999999999996
# Sentiment: Negative
# Text: A bad experience
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: I am stuck looking for a solution
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Bottom degenerates
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: After the unfortunate update, I can enter and say I forgot the password, how did you forget it 😡😡😡
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: Garbage in the full sense of the word, and to those who filed a complaint, Skoro, the complaint is really rubbish and; bad service
# Sentiment Polarity: -0.14999999999999997
# Sentiment: Negative
# Text: Attempting to update is very slow and heartbreaking
# Sentiment Polarity: -0.39000000000000007
# Sentiment: Negative
# Text: Very bad job
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: Very bad app and poor services
# Sentiment Polarity: -0.6549999999999999
# Sentiment: Negative
# Text: Bad bank, bad program, better transfer and easier transfer, Al-Rajhi Al-Ahly Bank is a failure.
# Sentiment Polarity: -0.3041666666666666
# Sentiment: Negative
# Text: After the update, it became completely unusable
# Sentiment Polarity: 0.1
# Sentiment: Positive
# Text: A very bad program, and I cannot enter it from my mobile because of the complications in the password between numbers and letters.
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: One of the worst human designs on the face of the simple is not good
# Sentiment Polarity: -0.3375
# Sentiment: Negative
# Text: It won't open despite dozens of attempts
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The new update failed, the application does not work, it was the best application, it became a failed application, treat your problems
# Sentiment Polarity: 0.03409090909090909
# Sentiment: Positive
# Text: The latest update is very bad, the application does not open with me and hangs
# Sentiment Polarity: -0.1366666666666666
# Sentiment: Negative
# Text: Honestly, after the update, it is very bad, but if it is worse than we said, the application does not open, and the attempt to log in is repeated a million times, and my form does not open. I clear my account in it
# Sentiment Polarity: -0.10166666666666664
# Sentiment: Negative
# Text: The app is very, very, very bad after the update and is not usable
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: I passed it as a weak application, and you cannot transfer or settle anything in it that is not useful, other than that.
# Sentiment Polarity: -0.21666666666666667
# Sentiment: Negative
# Text: The application after the update is very slow and when entering a local IBAN it says an error in the IBAN number and I tried a second IBAN and the same problem
# Sentiment Polarity: -0.09750000000000002
# Sentiment: Negative
# Text: Many problems I encountered in the inability to log in that the service is not available now
# Sentiment Polarity: 0.15
# Sentiment: Positive
# Text: The application has become bad over and over again. I don't know what the problem is. Every time I put the username and the secret code, it says wrong. It's been more than two weeks since the day I spoke.
# Sentiment Polarity: -0.27499999999999997
# Sentiment: Negative
# Text: After the update it got really bad
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: The update is not good at all. It is not possible to add an international beneficiary.. Develop the services better than you develop the graphics that overburden the program and make it stupid
# Sentiment Polarity: -0.12999999999999998
# Sentiment: Negative
# Text: very bad
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: Worst bank and worst app
# Sentiment Polarity: -1.0
# Sentiment: Negative
# Text: A failed and complex application and a failed update
# Sentiment Polarity: -0.43333333333333335
# Sentiment: Negative
# Text: Even with the latest update and changing the look of the application, there has been no change for the better. The application is bad and has many defects, including with the merger of the bank. Why is it not improved? You just earn money
# Sentiment Polarity: 0.20000000000000004
# Sentiment: Positive
# Text: Peace be upon you. Please solve the problem. The application does not open
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Mirror, see, update the old one inside, fast, without sending it to a mobile phone
# Sentiment Polarity: 0.15000000000000002
# Sentiment: Positive
# Text: After updating the new format, bank notifications are delayed
# Sentiment Polarity: 0.13636363636363635
# Sentiment: Positive
# Text: Application and update after a very bad salary from the day until today pending
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: The new app is very, very bad
# Sentiment Polarity: -0.3868181818181817
# Sentiment: Negative
# Text: The new version has many problems. After authentication, he rejects the process and gets out of the program, and we go back to recording, and he is crazy. Crazy version
# Sentiment Polarity: -0.11272727272727272
# Sentiment: Negative
# Text: After the update it got really bad
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: The latest updates are very unsuccessful, 3 days under maintenance, 2 days, and Yamin is suspended. What is your situation, National Bank?
# Sentiment Polarity: 0.35
# Sentiment: Positive
# Text: The last update is very bad
# Sentiment Polarity: -0.4549999999999999
# Sentiment: Negative
# Text: The application fails and has many malfunctions 👎👎👎
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very very bad and I advise not to download it
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: annoying
# Sentiment Polarity: -0.8
# Sentiment: Negative
# Text: An application that does not give you more special options, for example, you cannot inquire about your personal loan and the early payment feature. They cannot develop like the rest of the banks, such as Al-Rajhi Bank and its application
# Sentiment Polarity: 0.19142857142857145
# Sentiment: Positive
# Text: I can't download it
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: One of the cheapest applications and the lowest banks
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: A loser and garbage that does not open, sits and rolls without opening, I wish they would solve the problem
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The bank is bad, and it was the first bank for me to get a visa, but it was a thief who used to take a percentage greater than 3.75. Can it develop with the merger, who knows?!
# Sentiment Polarity: 0.05833333333333338
# Sentiment: Positive
# Text: The logo has become invalid, at least write the name of the bank in Arabic inside the logo (all logos are now similar and in the same colors)
# Sentiment Polarity: -0.09999999999999999
# Sentiment: Negative
# Text: It is not acceptable to save the password
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: I'm having trouble logging in and baptizing
# Sentiment Polarity: -0.2
# Sentiment: Negative
# Text: It is not satisfied that it is happening. I deleted the app and tried to install it
# Sentiment Polarity: -0.25
# Sentiment: Negative
# Text: loser
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: I have two days to update the application, it is very bad
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: Bad, needs a better update... It has become slow and stuck in moving from one operation to another
# Sentiment Polarity: -0.16666666666666663
# Sentiment: Negative
# Text: The bank's service is no longer what it used to be, as it asks to visit the nearest branch instead of carrying out any operation. Customer service equipment is most of the time under maintenance, and if it works after a few days of review, it refuses the fingerprint while it is accepted by the employee. However, Al-Ahly services are deteriorating if we compare them to the bank, which we consider to be a giant .
# Sentiment Polarity: 0.09999999999999999
# Sentiment: Positive
# Text: It does not load with me until now, 5 days ago and I am trying to download it
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Recently, the application has been hanging.. either when I open it or when I make a transfer
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very bad new app. The old one was very good
# Sentiment Polarity: 0.05909090909090911
# Sentiment: Positive
# Text: The instant transfer is done even in hour-old banks, and the National Bank until now. The problems of the instant transfer are something strange again, other than the secret number, the right of the bank phone that you set, and it returns to tell you the wrong number two days later. Star and forbidden, by God.
# Sentiment Polarity: -0.09866071428571428
# Sentiment: Negative
# Text: It does not support the activation of international transfer
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The cheapest bank to deal with and benefits
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: refused holds
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: What is this app? It's been a shame for me for about 6 months. I can't log in to my account and call the customer. He says there's a defect. How long will this manipulation be fixed? By God, I withdraw all my money and go to a second bank, I seek refuge in God.
# Sentiment Polarity: 0.016666666666666666
# Sentiment: Positive
# Text: Historic bank and failed app 😜
# Sentiment Polarity: -0.25
# Sentiment: Negative
# Text: The latest update has not spoken to me
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: The update hid some of the recorded information
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: He gets stuck and the baptism process is always a failure!!!?? The app tired me, it was great at first, and now it's gone
# Sentiment Polarity: 0.007877604166666663
# Sentiment: Positive
# Text: C very much
# Sentiment Polarity: 0.26
# Sentiment: Positive
# Text: The program does not work, requests an update, and it does not happen
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Bad update app stuck won't open
# Sentiment Polarity: -0.3499999999999999
# Sentiment: Negative
# Text: Suspended, not satisfied with entering after he sent me an update
# Sentiment Polarity: -0.25
# Sentiment: Negative
# Text: The new update refuses to open with me... bad👎🏻
# Sentiment Polarity: 0.06818181818181818
# Sentiment: Positive
# Text: God help you brother Bank
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The program does not work
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: I removed the Wazift Bank application
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Because the evaluation is compulsory, not optional, I want to enter my account, and I must evaluate the application before entering
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Never satisfied
# Sentiment Polarity: -0.25
# Sentiment: Negative
# Text: The program asks me to update, but there is no update! And suspended and suspended exchange!
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Unsatisfactory
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: I would like to add a service to buy credit for all telecom companies, as it allows the customer to benefit from this service. Buy credit and the card number will receive a message on the cell phone approved by the bank, as well as data balance for data segments. You see provided in all banks except Al-Ahly
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The app is sometimes unresponsive
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Problems after the update
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Failed application hangs
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: The last update is not working 😖😖😖😖
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: A program that does not work says it needs an update. You enter and tell you that there is no update. I deleted the program and returned it, the same problem
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: An application that fails every bit, two updates, is worse than before, banks are evolving, and you are behind a secret
# Sentiment Polarity: -0.42500000000000004
# Sentiment: Negative
# Text: The application has become very bad. Please pay attention to the criticism to log in. Where are you, Al-Ahly employees?
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: There is no refresh button
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: What did the new program open?
# Sentiment Polarity: 0.06818181818181818
# Sentiment: Positive
# Text: It got bad
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: Too bad, I'm worse than before
# Sentiment Polarity: -0.5499999999999999
# Sentiment: Negative
# Text: The application does not work. When I open the application, I see a message asking for an update, and I am transferred to Google Play. Unfortunately, there is no update
# Sentiment Polarity: -0.25
# Sentiment: Negative
# Text: Pending update
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Dislike
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: There is no update and the current version is requesting an update
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Where is the update
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The application does not work even though it has been updated. It has become very bad. I have to go to the National Bank website instead of the application
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: it's OK
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: I tried to log in.. pls refused... means the app is not working
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: C program every day the problem of entry
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The application does not open
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: the website does not work
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: I can't open the account
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The application does not open, it says a new version, and it tells me
# Sentiment Polarity: 0.06818181818181818
# Sentiment: Positive
# Text: We can't enter
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: An application from three months or more, and I am having difficulty entering the program and it gets stuck a lot
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: By God, it no longer opens. You ruined it after the update
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The problem of the update is blocking and preventing access. Why is it not optional? I am now unable to log into my account. Give me a solution????
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: Poor services from Jabbar Bank
# Sentiment Polarity: -0.4
# Sentiment: Negative
# Text: The new update is bad 👎 not working
# Sentiment Polarity: -0.28181818181818175
# Sentiment: Negative
# Text: The application does not want to be updated every day, the service is worse and broken, and there are no advantages
# Sentiment Polarity: -0.4
# Sentiment: Negative
# Text: The application does not open
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: It is very bad that you cannot log into your account. The wrong password or username is a fixed phrase in the program
# Sentiment Polarity: -0.43666666666666654
# Sentiment: Negative
# Text: What happened is not working and all that comes out to develop your experience is to update the program. You press update. There is no update. I deleted it and installed it again after asking for the update!!!!!!!!!!
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The app is very bad
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: The program requests an update and does not accept the update
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Failing and very heavy
# Sentiment Polarity: -0.26
# Sentiment: Negative
# Text: It asks me to update. Enter I want to update. There is no update!!
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The application does not accept the update permanently
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: It was nice, but unfortunately I have not been able to access my account for several months, especially from outside the Kingdom
# Sentiment Polarity: 0.09999999999999999
# Sentiment: Positive
# Text: it's OK .
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: dime hanging
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: I open the application and it shows me a new version that transfers me to the update, but there is no update and it hangs 😖
# Sentiment Polarity: 0.06818181818181818
# Sentiment: Positive
# Text: The program is not running, and every bit the program happened, and then it says the password is wrong
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: I open it and it says there is a new version. to update. OK to update. But it does not work.. The application has become tired.. Please return the first version.. and pay attention to the program. So that it becomes as easy to use as before.
# Sentiment Polarity: 0.15328282828282827
# Sentiment: Positive
# Text: Al-Ahly is not satisfied with speaking, I tried, and I do not know the reason
# Sentiment Polarity: -0.25
# Sentiment: Negative
# Text: Mukhais, Marouh, and a rotten bank.. no services or interest. By God, every month, as soon as my salary comes out, I transfer it all on the same day to my account in Al-Rajhi
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The new update has broken the app
# Sentiment Polarity: -0.13181818181818183
# Sentiment: Negative
# Text: Unfortunately, in the recent period, after modifying its identity and logo to merge with Samba Bank, the application no longer works and requires an update, but it is not activated for Android devices
# Sentiment Polarity: -0.25
# Sentiment: Negative
# Text: Weak
# Sentiment Polarity: -0.375
# Sentiment: Negative
# Text: The application does not work and requires an update. Please fix this matter
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Hanging open
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Every update gets worse
# Sentiment Polarity: -0.4
# Sentiment: Negative
# Text: I wish we had a safe pilgrimage.. The application has been updated and on the home page it takes me back to the update..Failed experience in updating
# Sentiment Polarity: 0.25
# Sentiment: Positive
# Text: Very bad challenge w and a bad bank, I do not advise anyone in it
# Sentiment Polarity: -0.8049999999999998
# Sentiment: Negative
# Text: The new update is pending until the previous one opens
# Sentiment Polarity: -0.015151515151515152
# Sentiment: Negative
# Text: It does not respond and does not work and always asks for an update. Uninstalled and re-downloaded, same issue
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: After the update, it actually refuses to log in to a large bank. This should not allow any error in its electronic applications
# Sentiment Polarity: 0.10714285714285714
# Sentiment: Positive
# Text: Bad program and I do not recommend dealing with the National Bank fraudsters
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: There is a problem that does not work
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The application is updated to the latest update and does not work. It requests an update even though it is the latest update
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: Not satisfied to open
# Sentiment Polarity: -0.125
# Sentiment: Negative
# Text: What is the application that is suspended 😥
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Where is the update so that we can remove the message that is sitting for us on the application door 😤
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The app is asking for an update and there is no update in the store!!
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: God willing, the application was good, until I updated it, it no longer works. May God break the hand of those who worked on the update 😡
# Sentiment Polarity: 0.475
# Sentiment: Positive
# Text: It does not work, writes in an update, but it is updated to the latest version!
# Sentiment Polarity: 0.625
# Sentiment: Positive
# Text: It does not work, writes in an update, but it is updated to the latest version!
# Sentiment Polarity: 0.625
# Sentiment: Positive
# Text: Zaffah is not working
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: not talking
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very bad and hung
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: Too bad..always hanging
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The program has been updated and tested
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The update is very very bad
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: Did not open
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Why can't I login to my debit card number?????
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: It needs development.. Look, for example, the application of Al-Rajhi and Al-Inmaa, its speed, ease, and smoothness. Your right is slow and old as a form
# Sentiment Polarity: 0.028571428571428553
# Sentiment: Positive
# Text: The application hangs
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: XVD application
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: C experience
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: It is difficult and does not work easily. Every time I open the application, it tires me. I hope to develop it
# Sentiment Polarity: -0.022222222222222216
# Sentiment: Negative
# Text: always loafers
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The app is very c
# Sentiment Polarity: 0.2
# Sentiment: Positive
# Text: Soooooooooooo program
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: It's hanging
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: There is a permanent problem. I cannot log in online easily. It always mentions an error in the name or password, and this is incorrect. Two days ago, I cannot log into my account.
# Sentiment Polarity: 0.43333333333333335
# Sentiment: Positive
# Text: The program has not been working for months
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: It doesn't work
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Not good, there is a problem
# Sentiment Polarity: -0.35
# Sentiment: Negative
# Text: It was very bad and now, God willing, the worst
# Sentiment Polarity: -0.5533333333333332
# Sentiment: Negative
# Text: The application does not work, every time we enter it says the password is wrong
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: I have more than 4 days and I am looking for a self-service machine so I can see an ATM and they are all idle. Why don't you care about customers and see them develop yourself so we can be with you
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: Why can't I enter from one time, and why do I have to try several times so that I waste my whole day trying! However, if it does not work, I remove the application and then re-download it until it opens with me. It is boring, and I am very upset with this application.
# Sentiment Polarity: -0.15
# Sentiment: Negative
# Text: The application does not work and it has been disrupted a lot. Why is Al-Ahly Bank used to be very good, but now it is very bad? Please pay attention to satisfy customers, thank you
# Sentiment Polarity: 5.551115123125783e-17
# Sentiment: Positive
# Text: Very bad application
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: The application is not currently working
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: No good services and no application that works as required. Advice, stay away from the National Bank, the worst bank currently..
# Sentiment Polarity: -0.45
# Sentiment: Negative
# Text: The application has had technical problems for a while, and the defect must be fixed, and customers must be respected, just like the rest of the distinguished banks in their electronic services, such as Al-Inmaa and others.
# Sentiment Polarity: 0.03333333333333333
# Sentiment: Positive
# Text: After the last update... very, very, very, very bad... As usual, don't be disappointed in any update!!
# Sentiment Polarity: -0.5399999999999999
# Sentiment: Negative
# Text: Once, the application is bad, and a bank like Al-Ahly is unable to modify its program
# Sentiment Polarity: -0.5999999999999999
# Sentiment: Negative
# Text: Bad application and maintenance takes a week. Ok, why do you put a bad application and it gets suspended
# Sentiment Polarity: -0.2999999999999999
# Sentiment: Negative
# Text: There is a problem and I can't log into my account
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: What relieves my heart is that you have lost many customers because of this bad application.
# Sentiment Polarity: -0.09999999999999992
# Sentiment: Negative
# Text: Very bad, the application has become updated and there is no benefit. I deleted it more than once, it is useless
# Sentiment Polarity: -0.3033333333333333
# Sentiment: Negative
# Text: Bad program
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: Unfortunately, there is a problem logging in
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: Tired application when you need it, it does not benefit you at the end of the night. It does not work and suspends services. If you need an account statement while you are outside the Kingdom, it tells you to go to the nearest ATM, smart, I am outside the country. Tired tired very different from the rest of the banks.
# Sentiment Polarity: -0.14081632653061224
# Sentiment: Negative
# Text: After merging the American, the application became bad
# Sentiment Polarity: -0.3499999999999999
# Sentiment: Negative
# Text: The program does not work after the new update
# Sentiment Polarity: 0.13636363636363635
# Sentiment: Positive
# Text: Too bad and there is no management to communicate with
# Sentiment Polarity: -0.6999999999999998
# Sentiment: Negative
# Text: Disabled during Saturday 6/12/2021
# Sentiment Polarity: -0.2
# Sentiment: Negative
# Text: Why is this app suspended? I don’t want to log in to my account, and I don’t want it to work 💔💔 It looks like I’m in my Al-Ahly account
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The program needs speed in navigating between menus, like the previous version, and currently the program has stopped working
# Sentiment Polarity: -0.08333333333333333
# Sentiment: Negative
# Text: Unfortunately, the app is missing a lot of updates
# Sentiment Polarity: -0.35
# Sentiment: Negative
# Text: From morning until now, the application is not working, it tells you that maintenance is disrupting people's interests
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The app hangs a lot
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: CC very much
# Sentiment Polarity: 0.26
# Sentiment: Positive
# Text: Very bad application and a lot of comments and malfunctions
# Sentiment Polarity: -0.9099999999999998
# Sentiment: Negative
# Text: You are not satisfied with me, write (we were unable to fulfill your request, please try again) I hope the problem is resolved.
# Sentiment Polarity: -0.375
# Sentiment: Negative
# Text: The application has become a failure after the last update.. and it is still failing even after 4/4
# Sentiment Polarity: -0.15833333333333335
# Sentiment: Negative
# Text: Unfortunately, the application does not work. Please correct the errors and work to solve them
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: A place of trust and respect in all his dealings
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Guaranteed services
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very nice and convenient program, thank you very much
# Sentiment Polarity: 0.52
# Sentiment: Positive
# Text: Successful
# Sentiment Polarity: 0.75
# Sentiment: Positive
# Text: A distinctive and concise application that facilitates the banking process
# Sentiment Polarity: 0.1
# Sentiment: Positive
# Text: well
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: beautiful
# Sentiment Polarity: 0.85
# Sentiment: Positive
# Text: Excellent time
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Really very comfortable and easy to use
# Sentiment Polarity: 0.4766666666666667
# Sentiment: Positive
# Text: Above excellent
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: My experience with the National Bank is great, but there is a problem with the application, sometimes it is very slow
# Sentiment Polarity: 0.205
# Sentiment: Positive
# Text: The best bank and the best app
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: very beautiful
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent and very easy
# Sentiment Polarity: 0.7816666666666667
# Sentiment: Positive
# Text: excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Fun and comfortable experience
# Sentiment Polarity: 0.35
# Sentiment: Positive
# Text: The application was excellent, but with the integration it changed
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Good at first
# Sentiment Polarity: 0.475
# Sentiment: Positive
# Text: Easy and practical application 👍
# Sentiment Polarity: 0.43333333333333335
# Sentiment: Positive
# Text: Very nice and easy to use program
# Sentiment Polarity: 0.6066666666666667
# Sentiment: Positive
# Text: Your program sucks
# Sentiment Polarity: -0.3
# Sentiment: Negative
# Text: thank God
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: become excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Very cool program
# Sentiment Polarity: 0.45499999999999996
# Sentiment: Positive
# Text: Excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: In short, refuse to enter me into the program
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Good once
# Sentiment Polarity: 0.7
# Sentiment: Positive
# Text: excellent with Honor's grade
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent and supported this application, but the problem of the user name did not appear, please fix it, and thank you
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: good
# Sentiment Polarity: 0.7
# Sentiment: Positive
# Text: Lovely
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: I advise you to bear it
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Great program
# Sentiment Polarity: 0.8
# Sentiment: Positive
# Text: useful
# Sentiment Polarity: 0.3
# Sentiment: Positive
# Text: Awesome
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Best. Selection
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: A very cool application, but now it is slow and takes up space
# Sentiment Polarity: 0.07749999999999996
# Sentiment: Positive
# Text: Program at its finest
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The app is good..
# Sentiment Polarity: 0.7
# Sentiment: Positive
# Text: I love the app
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: Sweet
# Sentiment Polarity: 0.35
# Sentiment: Positive
# Text: Fairly good
# Sentiment Polarity: 0.7
# Sentiment: Positive
# Text: Excellent, very, very best banking application in Saudi Arabia
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Very, very, very good
# Sentiment Polarity: 0.9099999999999999
# Sentiment: Positive
# Text: very good 💙
# Sentiment Polarity: 0.9099999999999999
# Sentiment: Positive
# Text: Good app for customer service
# Sentiment Polarity: 0.7
# Sentiment: Positive
# Text: Very acceptable
# Sentiment Polarity: 0.2
# Sentiment: Positive
# Text: Good app, but I can't do a conversion
# Sentiment Polarity: 0.7
# Sentiment: Positive
# Text: The best application
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: A beautiful and tried application, I am from the first, but the program is not afraid of it
# Sentiment Polarity: 0.46666666666666673
# Sentiment: Positive
# Text: I believed them
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: kind of good
# Sentiment Polarity: 0.6499999999999999
# Sentiment: Positive
# Text: The app is excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent experience
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent, but a lot of updates
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: A very excellent, easy and multi-service application.... Oh God, I provide someone with money in it, so that he forgets the needy and what he needed
# Sentiment Polarity: 0.7166666666666667
# Sentiment: Positive
# Text: Fast money transfer.
# Sentiment Polarity: 0.2
# Sentiment: Positive
# Text: It got better and easier
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: very easy
# Sentiment Polarity: 0.5633333333333334
# Sentiment: Positive
# Text: very good
# Sentiment Polarity: 0.9099999999999999
# Sentiment: Positive
# Text: Very excellent application
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent National Bank in all its steps
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent, short and easy to do a lot of operations
# Sentiment Polarity: 0.4777777777777778
# Sentiment: Positive
# Text: Mmmaz
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: A very excellent bank and excellent customer service..The services it sells are beautiful and very easy..The new updates are very nice
# Sentiment Polarity: 0.6610606060606061
# Sentiment: Positive
# Text: Qalyub branch
# Bosta is better than him and faster than him
# And their services are better
# Exploit yourselves in vain, I swear
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: Very nice and easy bank services and very excellent customer service..
# Sentiment Polarity: 0.7377777777777778
# Sentiment: Positive
# Text: I thank all the bank employees for their good, honest and quick response to recover the amount that was lost during the withdrawal from the exchange machine and was added to my account.
# May Allah reward them well.
# Sentiment Polarity: 0.5444444444444444
# Sentiment: Positive
# Text: It was a pleasure to deal with the Mall of Arabia online branch team. This team is the most professional, polite and cooperative I have met in any bank in Egypt. They worked hard to make everything happen between the branch team and the IT department. Keep up the great work 💪💪👌👌🤗🤗
# Sentiment Polarity: 0.27708333333333335
# Sentiment: Positive
# Text: I would like to thank the director of the hero branch, Ahmed Abdel Aziz, Mr. Osama Abdou Ali, his tiredness and efforts with the clients, is the real concern of the manager who helps the clients himself in order to raise the level of the bank. I mean, in exceptional cases for the clients, the branch manager moves all the time and follows up on the elephant and the validity of the papers, and follows up on the client. He follows up on the employees by phone. After a few minutes, the employee is late with his paper. The manager moves immediately, helps the employees and comes back. His office finishes the rest of the signatures one minute and goes back to the other one. I am very surprised that there are still employees in Egypt who are at the top of the integrity of the site where it is after working hours. I felt that we have risen very much in our transactions now in Egyptian banks 👍❤️🤝 Thank you, the National Bank of Egypt, the hero Ahmed Abdel Aziz branch 👌
# Sentiment Polarity: 0.07446969696969698
# Sentiment: Positive
# Text: Due thanks to Mr. Mohamed El-Sayed Wakeel and Deputy Director in the New Maadi branch for his professionalism, professionalism, high level of dealing and elegant style. He deserves all appreciation and respect for his sincerity and dedication in helping others to solve customer problems, even if they are very complex.
#
# Special thanks to Mr. Mohammed El-Sayed for his exceptional ownership and willingness to help all clients in their complex cases. Mr. Mohammed's attitude is very professional and friendly, and sets the bar very high for all other employees to follow.
# Sentiment Polarity: 0.14236951144094
# Sentiment: Positive
# Text: A right certificate for Mr. Ashraf Abdel-Fattah, one of the honorable symbols in the National Bank Inspection Department in Nazih Khaliga Street
# Where we went to him with a complaint and it was outside his competence, however, the meeting with him was in the utmost sophistication, taste and professionalism
# He cared about the issue as if it were his personal problem and more
# I couldn't believe when he solved a problem that lasted more than 40 days in less than 24 hours
# He returned the right to its owners
# He has many thanks and may God increase his likeness in all positions of responsibility
# Thanks to the management of the National Bank for the presence of such competencies
# Sentiment Polarity: 0.16706349206349205
# Sentiment: Positive
# Text: It is enough that it is excellent in all transactions and percentages
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: Today, I went to the National Bank Omar Ibn Al-Khattab branch, Heliopolis, because it was close to my house, 5 minutes before opening. I got number 12 and we got in right on opening time. This branch, due to its proximity to my house, frequented it a lot and expected at least two hours as usual. Today I found a system and a beehive, and after 15 minutes or less I was done. I asked if there was a new director, and as I expected, the answer was yes, a director on the second floor. Her good performance was reflected in all employees, even security. It was necessary to visit her office and congratulate her on this clear change and outstanding performance. These rare models deserve praise and salute.
# Sentiment Polarity: 0.07002937538651824
# Sentiment: Positive
# Text: I would like to thank the bank for a genuine customer service over the phone, fast and efficient.. Please do not change the process..
# Sentiment Polarity: 0.30000000000000004
# Sentiment: Positive
# Text: Hello
# As we talk about the negatives, we must talk about the positives as well
# Today I went to the Al-Ahly Bank, Al-Khalifa branch, located in Mansoura, on Al-Teraa Street
# Naturally, it is the first working day after the Eid holiday, and the number of clients will be many. He will distribute the numbers to us inside the branch.. Really a kind gesture, and I thank him even though I do not know him personally, and I pray to God that the rest of him will be free on the Day of Resurrection, as He has mercy on us from standing in the sun to wait our turn
# Sentiment Polarity: 0.30833333333333335
# Sentiment: Positive
# Text: Today, for the first time, I visit the main branch where I have my account, but unfortunately I have never gone to it before
# Seriously, the best branch of the National Bank is order and respect, and the managers are standing in the middle of where the employees are, not sitting at desks unlike any other branch. They follow who is working and who is lazy, and see who is empty. Customers enter. I mean, I was short on my turn of about 35 clients, and yet I did not sit for half an hour if I had any other branch, by God. I take all day
# I sincerely thank the staff and managers in the main branch for their respect and diligence.
# Sentiment Polarity: 0.011388888888888884
# Sentiment: Positive
# Text: Today, I had the pleasure of dealing with His Excellency Mr. Yasser Abu Al-Saud, Director of the National Bank of Egypt, Al-Rehab Branch
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: You are honest and have easier dealings with you and respect your highness
# Sentiment Polarity: 0.6
# Sentiment: Positive
# Text: National Bank of Egypt Everyone needs a good life. Save our benefits, and increase the wealth of our fetus. I love National Bank of Oman. my wishes.
# Sentiment Polarity: 0.6
# Sentiment: Positive
# Text: The treatment is good, morals and taste, and the dates are perfect
# Sentiment Polarity: 0.85
# Sentiment: Positive
# Text: Peace, mercy, and blessings of God be upon you. Happy new year, health, wellness, and happiness. The service of the National Bank is excellent, and it has many areas to meet the services of citizens. I ask for help and activate the visa. My name is Muhammad Hassan Mahmoud Hassan Ali.
# Sentiment Polarity: 0.6272727272727272
# Sentiment: Positive
# Text: Al-Ahly Bank of Egypt is the best bank in Egypt. May God always be at the forefront
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: The pride of Egyptian and Arab banks
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: I would like to commend the efforts of Mr. Ahmed Ismail, Call Center Customer Service Manager, for his excellent handling of my issue with my Visa card on April 28th. Critical issue I was having and follow up until the issue is resolved. Thank you Mr Ahmed, you are a role model!
# Sentiment Polarity: 0.3
# Sentiment: Positive
# Text: Peace be upon you
# I have the honor to submit my complaint to the higher management of the National Bank of Egypt because I submitted a request to cancel my credit card from the Zagazig Syndicates branch, and I edited the form prepared for that
# But so far, the card has not been canceled and all its debts have been paid from the certificates of deposit with the bank
#  Ahmed Fathi Abdullah
# National
# 27105101300151
# 01012176527
# Sentiment Polarity: 0.016666666666666673
# Sentiment: Positive
# Text: Thank you, and if I wish for more interaction regarding customer problems
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: A bank that has its weight and prestige and is a pioneer in the development of banking services :-)
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: The best bank in Africa. :-)
# Sentiment Polarity: 0.75
# Sentiment: Positive
# Text: Ahl Misr Bank ..................
# The best bank in Egypt
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: This is very nice, but it needs an exit button. When you enter, you need to exit, but it is not there. What makes you exit without security? I mean, you press the back button, and it is useless. Please put the exit button.
# Sentiment Polarity: -0.008124999999999993
# Sentiment: Negative
# Text: Excellent service. I wish you good health
# Sentiment Polarity: 0.85
# Sentiment: Positive
# Text: Very sweet
# Sentiment Polarity: 0.45499999999999996
# Sentiment: Positive
# Text: I adore you crazy 😘😘
# Sentiment Polarity: -0.6
# Sentiment: Negative
# Text: I thank everyone who contributed to this program, may God bless everyone
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Excellent location
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Mrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr sweet do not miss
# Sentiment Polarity: 0.35
# Sentiment: Positive
# Text: It became much better than the first and easy
# Sentiment Polarity: 0.39444444444444443
# Sentiment: Positive
# Text: A very cool program that helps meet needs faster
# Sentiment Polarity: 0.45499999999999996
# Sentiment: Positive
# Text: very nice wonderful. . .
# Sentiment Polarity: 0.89
# Sentiment: Positive
# Text: There is a lot of improvement in customer service. They are kind to some technical errors, but you fix them quickly, and some delays. Your politics and marketing have become better than Karim for me. We agree.
# Sentiment Polarity: 0.35833333333333334
# Sentiment: Positive
# Text: The app does not work in Baghdad
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: rigid
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: very good
# Sentiment Polarity: 0.9099999999999999
# Sentiment: Positive
# Text: death
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Awesome
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Nice, but I couldn't make an account
# Sentiment Polarity: 0.6
# Sentiment: Positive
# Text: Praise be to God, the officials responsible for Talabat have been contacted and they returned me to Talabat account with any amount of the wrong product. Honestly, this is too much.
# Sentiment Polarity: 0.125
# Sentiment: Positive
# Text: 0 kg line. true
# Sentiment Polarity: 0.35
# Sentiment: Positive
# Text: Very good and excellent service. It has everything you need from a supermarket, famous restaurants, and many other things
# Sentiment Polarity: 0.557
# Sentiment: Positive
# Text: five stars
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Great app
# Sentiment Polarity: 0.8
# Sentiment: Positive
# Text: Without any lie, this application is crazy, and do not care about the comments of the traitors. Thank you for this program
# Sentiment Polarity: -0.6
# Sentiment: Negative
# Text: Special
# Sentiment Polarity: 0.35714285714285715
# Sentiment: Positive
# Text: I love everything about it
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: Much special. ..............
# Sentiment Polarity: 0.35714285714285715
# Sentiment: Positive
# Text: Very nice application, thanks for your efforts
# Sentiment Polarity: 0.49
# Sentiment: Positive
# Text: Mmmm, excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Successful experience with requests, well done
# Sentiment Polarity: 0.75
# Sentiment: Positive
# Text: Sorry, what is the benefit? Most of the sites cannot be delivered, especially grocery stores, which are few in the program. Restaurants are abundant.. Excellent service, but it needs development.
# Sentiment Polarity: 0.2333333333333333
# Sentiment: Positive
# Text: The best company
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: How can expired coupons be redeemed?
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The best application in the world as long as without advertising
# Sentiment Polarity: 0.475
# Sentiment: Positive
# Text: Wonderful application, thanks Talabat
# Sentiment Polarity: 0.6
# Sentiment: Positive
# Text: The best food delivery program in Iraq in all respects
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: An unfair program
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: Mmnaz
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Zd1 p. 3 p
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very excellent, and thank you for your interest
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Frankly, Talabat is a wonderful and very comfortable thing, and at any time you ask for what you have in mind. Good luck, Lord, and God willing, the application will develop more and become in all fields
# Sentiment Polarity: 0.594
# Sentiment: Positive
# Text: I can't download the app.. I've been trying to download the app for days, but to no avail
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Excellent and useful program
# Sentiment Polarity: 0.65
# Sentiment: Positive
# Text: Excellent application, but how do I register my own restaurant, but rather an application
# Sentiment Polarity: 0.8
# Sentiment: Positive
# Text: Their services are excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent, it serves people and society
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Great app that saves time and effort
# Sentiment Polarity: 0.8
# Sentiment: Positive
# Text: I hope to process the application with the best processors
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: God is sweet and delivers at any time
# Sentiment Polarity: 0.35
# Sentiment: Positive
# Text: Delivery service is fast and good 👍👍
# Sentiment Polarity: 0.44999999999999996
# Sentiment: Positive
# Text: Very nice hands
# Sentiment Polarity: 0.78
# Sentiment: Positive
# Text: Thanks for making the program 👏👏
# Sentiment Polarity: 0.2
# Sentiment: Positive
# Text: Islam Hassanein OK
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: Excellent excellent service
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Go crazy
# Sentiment Polarity: -0.6
# Sentiment: Negative
# Text: What is the need for marriage
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Good Jin and your assistant also, thank you very much
# Sentiment Polarity: 0.48
# Sentiment: Positive
# Text: Very wonderful, may God reward you
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: An excellent application, a lot, and I advise everyone to use it
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Thank you for making the service easier for us
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: A very excellent application, I recommend downloading it
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Five-star restaurant delivery orders are free
# Sentiment Polarity: 0.4
# Sentiment: Positive
# Text: Thank you for your service and quick response to complaints and taking them seriously
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Oh God, I ask you for a reassuring soul that believes in meeting you and is satisfied with your decree and is content with your giving
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: Beautiful and wonderful
# Sentiment Polarity: 0.925
# Sentiment: Positive
# Text: Fast delivery
# Sentiment Polarity: 0.2
# Sentiment: Positive
# Text: Very nice and recommend. with it
# Sentiment Polarity: 0.78
# Sentiment: Positive
# Text: The application always develops itself to serve customers
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Ha-ha-ha-ha-ha-ha-ha-ha-ha
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Best experience ever
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: A quick application and all foods and restaurants are available 👍🏻
# Sentiment Polarity: 0.3666666666666667
# Sentiment: Positive
# Text: Once I ordered Claire and I got a kunafa 😭😂
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very convenient application
# Sentiment Polarity: 0.2
# Sentiment: Positive
# Text: Good, but I hope to add more restaurants and markets
# Sentiment Polarity: 0.6
# Sentiment: Positive
# Text: The app is very good after it solved the problem I was facing #fast_delivery_app
# Sentiment Polarity: 0.9099999999999999
# Sentiment: Positive
# Text: Awesome app
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: I tell Talabat to be honest. I like their interest and the speed of solving the problem, but I have a problem that makes me look for an alternative program. The reason is that sometimes the card goes away and sometimes it doesn’t. I call the bank and they say the problem is from the program. Since yesterday, I asked Sun Mart with the card, it’s useless.
# Sentiment Polarity: 0.04999999999999999
# Sentiment: Positive
# Text: Today I ordered the same order more than 10 times, and each time they deducted 98 riyals from me, and the order did not arrive.
# Sentiment Polarity: 0.25
# Sentiment: Positive
# Text: The application is very excellent. And wonderful
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: delicious
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Wow, great taste.
# Sentiment Polarity: 0.45
# Sentiment: Positive
# Text: No, I swear to God, I want you to fall asleep
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The app is a weird thing to download
# Sentiment Polarity: -0.5
# Sentiment: Negative
# Text: A very nice program, fast delivery, and their treatment is very nice 🤍💓💓 I thank all those who work in this company 🤍
# Sentiment Polarity: 0.5866666666666667
# Sentiment: Positive
# Text: Excellent and important in times of your individual and collective need. What is appropriate for you will be received. Thank you.
# Sentiment Polarity: 0.475
# Sentiment: Positive
# Text: Very cool
# Sentiment Polarity: 0.45499999999999996
# Sentiment: Positive
# Text: Awesome really nice
# Sentiment Polarity: 0.8
# Sentiment: Positive
# Text: Hello
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Nice application, don't believe anyone who tells you that it is a beast and fast in delivery. Thank you for making the application
# Sentiment Polarity: 0.4
# Sentiment: Positive
# Text: Once in a while beautiful
# Sentiment Polarity: 0.85
# Sentiment: Positive
# Text: Great and useful application
# Sentiment Polarity: 0.55
# Sentiment: Positive
# Text: What is it talking about
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Excellent and wonderful program
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: There is a problem with the application. When I come to a request, it does not come to me. Please solve the problem as soon as possible
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very excellent program
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Excellent service in terms of product quality, delivery and packaging. The delivery workers are top notch in politeness and ethics
# Sentiment Polarity: 0.75
# Sentiment: Positive
# Text: Better than awesome
# Sentiment Polarity: 0.75
# Sentiment: Positive
# Text: nice
# Sentiment Polarity: 0.6
# Sentiment: Positive
# Text: Literally thugs, the best delivery app in Jordan, as much as one has tried it, I'm back on orders ♥️😇
# Sentiment Polarity: 0.39999999999999997
# Sentiment: Positive
# Text: In the name of God, whatever God wills
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: The splendor of swallowing right
# Sentiment Polarity: 0.2857142857142857
# Sentiment: Positive
# Text: ? H;; the i9? O..L L.O.?? Text you copy will automatically appear hereText you copy will automatically appear here
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Abha Hassan Muhammad 🇲🇴🇲🇴🇲🇴🇲🇴🇲🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯🍯
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Good application but ordering is delayed in restaurants
# Sentiment Polarity: 0.7
# Sentiment: Positive
# Text: Very nice
# Sentiment Polarity: 0.78
# Sentiment: Positive
# Text: Very good app how can we get coupons
# Sentiment Polarity: 0.9099999999999999
# Sentiment: Positive
# Text: Requests other than the form of very Zuouq, God
# Sentiment Polarity: 0.037500000000000006
# Sentiment: Positive
# Text: Very cool
# Sentiment Polarity: 0.45499999999999996
# Sentiment: Positive
# Text: The program is great, but it does not open on my mobile. Every time I open it, it closes and my phone has storage space and strong internet. The update is almost too high on my phone. My phone type is (Huawei 2017). It is possible to reduce the update
# Sentiment Polarity: 0.23222222222222222
# Sentiment: Positive
# Text: His vision
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: very good
# Sentiment Polarity: 0.9099999999999999
# Sentiment: Positive
# Text: Seey requests
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Peace be upon you, I wish there would be delivery from Dubai to Sharjah and back, and from Ajman to Sharjah and back
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: This app is awesome and made me happy with many things
# Sentiment Polarity: 0.7666666666666666
# Sentiment: Positive
# Text: Very good, to a great extent.. but I hope to have room to amend my evaluation of the service provider or put a delete option for re-evaluation in general, thank you.
# Sentiment Polarity: 0.5866666666666667
# Sentiment: Positive
# Text: I deleted everything, and I'm still downloading and getting an update
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Nice, please, I don't know what an update means, and I'm not working
# Sentiment Polarity: 0.6
# Sentiment: Positive
# Text: Diettttttt Nazlo crazy hahaha bye
# Sentiment Polarity: -0.19999999999999998
# Sentiment: Negative
# Text: There is nothing better than this
# Sentiment Polarity: 0.5
# Sentiment: Positive
# Text: go crazy
# Sentiment Polarity: -0.6
# Sentiment: Negative
# Text: Zayn is very sweet
# Sentiment Polarity: 0.45499999999999996
# Sentiment: Positive
# Text: My lines
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Crazy
# Sentiment Polarity: -0.6
# Sentiment: Negative
# Text: Imaginary
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Wonderful, and good luck, Lord ⚘
# Sentiment Polarity: 0.85
# Sentiment: Positive
# Text: May I know when the order will be delivered?
# Sentiment Polarity: 0.0
# Sentiment: Negative
# Text: Very cool, but there is no discount
# Sentiment Polarity: 0.45499999999999996
# Sentiment: Positive
# Text: Excellent
# Sentiment Polarity: 1.0
# Sentiment: Positive
# Text: Wow
# Sentiment Polarity: 0.1
# Sentiment: Positive

# %%
predicted_class
# Out:
# ['Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive']

# %%
actual_class
# Out:
# 0      Negative
# 1      Negative
# 2      Negative
# 3      Negative
# 4      Negative
#          ...
# 444    Positive
# 445    Positive
# 446    Positive
# 447    Positive
# 448    Positive
# Name: Class, Length: 449, dtype: object

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(predicted_class,actual_class)

# %%
cm
# Out:
# array([[188,  50],
#        [ 41, 170]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(predicted_class,actual_class)
# Out:
# 0.7973273942093542

# %%
from sklearn.metrics import classification_report
print(classification_report(predicted_class,actual_class))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.82      0.79      0.81       238
#     Positive       0.77      0.81      0.79       211
#
#     accuracy                           0.80       449
#    macro avg       0.80      0.80      0.80       449
# weighted avg       0.80      0.80      0.80       449

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.heatmap(cm, annot=True, cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
import matplotlib.pyplot as plt
TN=188
FP=41
TP=170
FN=50

# Calculate metrics
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1_score = 2 * (precision * recall) / (precision + recall)

# Create a bar graph
labels = ['TN', 'FP', 'TP', 'FN']
values = [TN, FP, TP, FN]

plt.bar(labels, values, color=['pink', 'brown', 'yellow', 'green'])
plt.xlabel('Confusion Matrix Based on Textblob')
plt.ylabel('Count')
plt.title('Confusion Matrix')
plt.show()

# Print additional metrics
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1_score:.2f}')
# Out:
# Precision: 0.81
# Recall: 0.77
# F1 Score: 0.79
